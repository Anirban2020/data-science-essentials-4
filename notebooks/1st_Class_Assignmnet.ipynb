# %%
import pandas as pd

# %%
hospitals = pd.read_csv('../data/Hospitals.csv')

# %%
hospitals.head(2)
# Out:
#               X             Y  OBJECTID        ID  \
# 0 -1.331889e+07  4.346975e+06         1   5793230
# 1 -1.322651e+07  4.049626e+06         2  53391362
#
#                                                 NAME                  ADDRESS  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL  1025 NORTH DOUTY STREET
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...           150 VIA MERIDA
#
#               CITY STATE    ZIP           ZIP4  ...             VAL_DATE  \
# 0          HANFORD    CA  93230  NOT AVAILABLE  ...  2014/02/10 00:00:00
# 1  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE  ...  2014/02/10 00:00:00
#
#                             WEBSITE       STATE_ID       ALT_NAME ST_FIPS  \
# 0      http://www.hanfordhealth.com  NOT AVAILABLE  NOT AVAILABLE       6
# 1  http://www.losrobleshospital.com  NOT AVAILABLE  NOT AVAILABLE       6
#
#          OWNER TTL_STAFF  BEDS         TRAUMA  HELIPAD
# 0  PROPRIETARY      -999    49  NOT AVAILABLE        N
# ...

# %%
hospitals.tail(2)
# Out:
#                  X             Y  OBJECTID         ID  \
# 7594 -8.522423e+06  4.718512e+06      7610  191021401
# 7595 -1.244921e+07  4.976468e+06      7611  196784108
#
#                                     NAME                     ADDRESS  \
# 7594  J KENT MCNEW FAMILY MEDICAL CENTER  175 HARRY S TRUMAN PARKWAY
# 7595       UNIVERSITY ORTHOPAEDIC CENTER              590 WAKARA WAY
#
#                 CITY STATE    ZIP           ZIP4  ...             VAL_DATE  \
# 7594       ANNAPOLIS    MD  21401  NOT AVAILABLE  ...  2020/05/05 00:00:00
# 7595  SALT LAKE CITY    UT  84108  NOT AVAILABLE  ...  2020/05/05 00:00:00
#
#                                                 WEBSITE       STATE_ID  \
# 7594  https://aahs.org/locations/j--kent-mcnew-famil...  NOT AVAILABLE
# 7595          https://healthcare.utah.edu/orthopaedics/  NOT AVAILABLE
#
#            ALT_NAME ST_FIPS               OWNER TTL_STAFF  BEDS  \
# 7594  NOT AVAILABLE      24          NON-PROFIT      -999  -999
# ...

# %% [markdown]
# Looking at the first and last few rows it looks like to be dataset of hsopitals from across the country with
# various details such as their location,website, number of beds etc.

# %%
hospitals.shape
# Out:
# (7596, 34)

# %% [markdown]
# Number of rows is 7596 and columns is 34.

# %%
hospitals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7596 entries, 0 to 7595
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           7596 non-null   float64
#  1   Y           7596 non-null   float64
#  2   OBJECTID    7596 non-null   int64
#  3   ID          7596 non-null   int64
#  4   NAME        7596 non-null   object
#  5   ADDRESS     7596 non-null   object
#  6   CITY        7596 non-null   object
#  7   STATE       7596 non-null   object
#  8   ZIP         7596 non-null   int64
#  9   ZIP4        7596 non-null   object
#  10  TELEPHONE   7596 non-null   object
#  11  TYPE        7596 non-null   object
#  12  STATUS      7596 non-null   object
#  13  POPULATION  7596 non-null   int64
#  14  COUNTY      7596 non-null   object
#  15  COUNTYFIPS  7596 non-null   object
#  16  COUNTRY     7596 non-null   object
#  17  LATITUDE    7596 non-null   float64
#  18  LONGITUDE   7596 non-null   float64
# ...

# %%
hospitals_trimmed=hospitals[['NAME', 'ADDRESS', 'CITY', 'STATE', 'TYPE',  'POPULATION', 'COUNTY', 'COUNTYFIPS', 'NAICS_DESC', 'BEDS']]

# %%
hospitals_trimmed.shape
# Out:
# (7596, 10)

# %%
hospitals['TYPE'].value_counts()
# Out:
# GENERAL ACUTE CARE    4481
# CRITICAL ACCESS       1027
# PSYCHIATRIC            759
# LONG TERM CARE         431
# REHABILITATION         378
# MILITARY               216
# SPECIAL                145
# CHILDREN               130
# WOMEN                   20
# CHRONIC DISEASE          9
# Name: TYPE, dtype: int64

# %% [markdown]
# The different hospital types are 10 in number with General Acute Care being the most popular

# %% [markdown]
# hospitals_trimmed['CITY'].value_counts()

# %%
hospitals_trimmed_Nashville = hospitals_trimmed.loc[hospitals_trimmed['CITY'] == 'NASHVILLE']

# %%
hospitals_trimmed_Nashville_TN = hospitals_trimmed_Nashville.loc[hospitals_trimmed_Nashville['STATE'] == 'TN']

# %%
hospitals_trimmed_Nashville_TN.shape
# Out:
# (13, 10)

# %%
hospitals_trimmed_Nashville_TN
# Out:
#                                                NAME  \
# 545                  TRISTAR SKYLINE MEDICAL CENTER
# 3449          SELECT SPECIALTY HOSPITAL - NASHVILLE
# 3485                           CURAHEALTH NASHVILLE
# 5429             THE WOMEN'S HOSPITAL AT CENTENNIAL
# 5433        METROPOLITAN NASHVILLE GENERAL HOSPITAL
# 6289                  SAINT THOMAS MIDTOWN HOSPITAL
# 6293  VANDERBILT STALLWORTH REHABILITATION HOSPITAL
# 6661           VA MEDICAL CENTER - NASHVILLE CAMPUS
# 6774    SAINT THOMAS HOSPITAL FOR SPECIALTY SURGERY
# 6777                     SAINT THOMAS WEST HOSPITAL
# 6786          TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 6808              TRISTAR CENTENNIAL MEDICAL CENTER
# 6813                 VANDERBILT UNIVERSITY HOSPITAL
#
#                              ADDRESS       CITY STATE                TYPE  \
# 545              3441 DICKERSON PIKE  NASHVILLE    TN  GENERAL ACUTE CARE
# 3449    2000 HAYES STREET, SUITE 500  NASHVILLE    TN      LONG TERM CARE
# ...

# %% [markdown]
# The beds column is varied with some having as low as 23 and some having as high 1091. One hospital has -999 beds which
# did not made sense to me.

# %%
hospitals_TN = hospitals.loc[hospitals['STATE'] == 'TN']

# %%
hospitals_TN
# Out:
#                  X             Y  OBJECTID         ID  \
# 515  -9.409026e+06  4.210878e+06       517   14737331
# 535  -9.535209e+06  4.348723e+06       537    3438562
# 536  -9.692242e+06  4.246701e+06       538    8038401
# 537  -9.891187e+06  4.257288e+06       539    8338305
# 540  -9.830658e+06  4.341502e+06       542    6538242
# ...            ...           ...       ...        ...
# 6810 -9.630429e+06  4.377577e+06      6823    2637148
# 6811 -9.636394e+06  4.297187e+06      6824   10737167
# 6812 -9.174179e+06  4.319023e+06      6825   10137650
# 6813 -9.662773e+06  4.320018e+06      6826   15837232
# 7362 -9.177696e+06  4.316931e+06      7376  195337650
#
#                                           NAME                    ADDRESS  \
# 515       STARR REGIONAL MEDICAL CENTER ETOWAH      886 HIGHWAY 411 NORTH
# 535                    JACKSON COUNTY HOSPITAL         620 HOSPITAL DRIVE
# 536                    MAURY REGIONAL HOSPITAL       1224 TROTWOOD AVENUE
# ...

# %%
hospitals_TN['COUNTY'].nunique()
# Out:
# 80

# %%
hospitals_TN['COUNTY'].value_counts()
# Out:
# SHELBY        23
# DAVIDSON      15
# HAMILTON      13
# KNOX          11
# WASHINGTON     6
#               ..
# JACKSON        1
# MAURY          1
# HARDEMAN       1
# HARDIN         1
# LOUDON         1
# Name: COUNTY, Length: 80, dtype: int64

# %% [markdown]
# The Shelby county has the highest number of hospitals. 15 counties don't have a single hospital.
